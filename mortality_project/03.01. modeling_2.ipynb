# %%
import pandas as pd

# %%
train_df = pd.read_csv('C:/project/physionet2012/preprocessed_train_data.csv', encoding='cp949')
valid_df = pd.read_csv('C:/project/physionet2012/preprocessed_valid_data.csv', encoding='cp949')
test_df = pd.read_csv('C:/project/physionet2012/preprocessed_test_data.csv', encoding='cp949')

# %%
train_df.to_csv('C:/project/physionet2012/preprocessed_train_data.csv', encoding='cp949',index=False)
valid_df.to_csv('C:/project/physionet2012/preprocessed_valid_data.csv', encoding='cp949',index=False)
test_df.to_csv('C:/project/physionet2012/preprocessed_test_data.csv', encoding='cp949',index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-d9ebef1d07b7> in <module>
# ----> 1 train_df.to_csv('C:/project/physionet2012/preprocessed_train_data.csv', encoding='cp949',index=False)
#       2 valid_df.to_csv('C:/project/physionet2012/preprocessed_valid_data.csv', encoding='cp949',index=False)
#       3 test_df.to_csv('C:/project/physionet2012/preprocessed_test_data.csv', encoding='cp949',index=False)
#
# NameError: name 'train_df' is not defined

# %%
df3 = pd.concat([df1,tar], axis=1)
