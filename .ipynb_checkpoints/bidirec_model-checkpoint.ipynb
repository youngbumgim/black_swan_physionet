# %% [markdown]
# # physionet2012 데이터 전처리
# - 데이터 가져오기
# - scaler 가져오기
# - X, y 분리하기
# - scaler 적용하기
# - model에 입력가능한 3차원 형태 데이터 만들기
# - (batch_size, maxlen, feature_dim)

# %%
# 전처리된 데이터 가져오기

import numpy as np
import pandas as pd

path = '/Users/jsha/gjai/final_project/black_swan_physionet/'
file = 'train_done_preprocessing.csv'
file2 = 'valid_done_preprocessing.csv'
file3 = 'test_done_preprocessing.csv'

train_df = pd.read_csv(path+file)
valid_df = pd.read_csv(path+file2)
test_df = pd.read_csv(path+file3)

maxlen = len(train_df[train_df['pid'] == train_df['pid'][0]])

# %%
len(train_df.columns)
# Out:
# 46

# %%
# labels 컬럼 인덱스 찾기
inx = test_df.columns.get_indexer(['labels'])
print(inx)

# X, y 분리
y_train = train_df['labels']
X_train_nonorm = train_df.drop(columns=['pid', 'Gender', 'survival', 'surv_los', 'LOS', 'labels'])
print(y_train.shape)
print(X_train_nonorm.shape)

y_valid = valid_df['labels']
X_valid_nonorm = valid_df.drop(columns=['pid', 'Gender', 'survival', 'surv_los', 'LOS', 'labels'])
print(y_valid.shape)
print(X_valid_nonorm.shape)

y_test = test_df['labels']
X_test_nonorm = test_df.drop(columns=['pid', 'Gender', 'survival', 'surv_los', 'LOS', 'labels'])
print(y_test.shape)
print(X_test_nonorm.shape)
# Out:
# [41]
# (226800,)
# (226800, 40)
# (25200,)
# (25200, 40)
# (28000,)
# (28000, 40)

# %%
# scaler를 이용한 정규화

import pickle

mms = 'mms.pickle'
with open(path+mms, 'rb') as handler:
    load_mms = pickle.load(handler)
    
X_train = load_mms.transform(X_train_nonorm)
X_valid = load_mms.transform(X_valid_nonorm)
X_test = load_mms.transform(X_test_nonorm)

print(X_train.shape)
print(y_train.shape)
X_train_3d = X_train.reshape((-1, maxlen, X_train.shape[-1]))
print(X_train_3d.shape)
y_train_3d = y_train[::maxlen]
print(y_train_3d.shape)

X_valid_3d = X_valid.reshape((-1, maxlen, X_valid.shape[-1]))
print(X_valid_3d.shape)
y_valid_3d = y_valid[::maxlen]
print(y_valid_3d.shape)

X_test_3d = X_test.reshape((-1, maxlen, X_test.shape[-1]))
print(X_test_3d.shape)
y_test_3d = y_test[::maxlen]
print(y_test_3d.shape)
# Out:
# (226800, 40)
# (226800,)
# (3240, 70, 40)
# (3240,)
# (360, 70, 40)
# (360,)
# (400, 70, 40)
# (400,)

# %% [markdown]
# # Model 설계

# %% [markdown]
# ## bidirectional_model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Flatten, Bidirectional, Input

max_len = len(X_train_3d[0])
feature_dim = X_train_3d.shape[-1]

bidirec_model = Sequential()
bidirec_model.add(LSTM(64, activation='tanh', input_shape=(max_len, feature_dim), return_sequences=True))
bidirec_model.add(Bidirectional(LSTM(64)))
bidirec_model.add(Dropout(0.5))
bidirec_model.add(Dense(32, activation='relu'))
bidirec_model.add(Dropout(0.5))
bidirec_model.add(Dense(8, activation='relu'))
bidirec_model.add(Dense(1, activation='sigmoid'))

# %%
bidirec_model.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_9 (LSTM)               (None, 70, 64)            26880
#
#  bidirectional_5 (Bidirectio  (None, 128)              66048
#  nal)
#
#  dropout_11 (Dropout)        (None, 128)               0
#
#  dense_15 (Dense)            (None, 32)                4128
#
#  dropout_12 (Dropout)        (None, 32)                0
#
#  dense_16 (Dense)            (None, 8)                 264
#
#  dense_17 (Dense)            (None, 1)                 9
#
# =================================================================
# Total params: 97,329
# Trainable params: 97,329
# Non-trainable params: 0
# _________________________________________________________________

# %%
bidirec_model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['acc', 'AUC'])

# %%
# 모델 학습하기

from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

epochs = 20
batch_size = 40
model_name = 'chp_bidirec_model.h5'

early_stopping = EarlyStopping(monitor='val_auc', patience=4, verbose=1)
checkpoint = ModelCheckpoint(path+model_name, monitor='val_auc', save_best_only=True)

history = bidirec_model.fit(X_train_3d, y_train_3d, epochs=epochs, batch_size=batch_size, 
                    validation_data=(X_valid_3d, y_valid_3d), callbacks=[early_stopping, checkpoint])
# Out:
# Epoch 1/20
# 81/81 [==============================] - 9s 60ms/step - loss: 0.4679 - acc: 0.8519 - auc: 0.4997 - val_loss: 0.3994 - val_acc: 0.8639 - val_auc: 0.5000
# Epoch 2/20
# 81/81 [==============================] - 4s 47ms/step - loss: 0.4129 - acc: 0.8679 - auc: 0.5024 - val_loss: 0.4064 - val_acc: 0.8639 - val_auc: 0.5362
# Epoch 3/20
# 81/81 [==============================] - 4s 46ms/step - loss: 0.4069 - acc: 0.8682 - auc: 0.5138 - val_loss: 0.4054 - val_acc: 0.8639 - val_auc: 0.5533
# Epoch 4/20
# 81/81 [==============================] - 4s 46ms/step - loss: 0.3963 - acc: 0.8682 - auc: 0.5473 - val_loss: 0.3933 - val_acc: 0.8639 - val_auc: 0.7105
# Epoch 5/20
# 81/81 [==============================] - 4s 48ms/step - loss: 0.3960 - acc: 0.8685 - auc: 0.5689 - val_loss: 0.4111 - val_acc: 0.8639 - val_auc: 0.6524
# Epoch 6/20
# 81/81 [==============================] - 4s 48ms/step - loss: 0.3793 - acc: 0.8685 - auc: 0.6368 - val_loss: 0.3621 - val_acc: 0.8639 - val_auc: 0.7547
# Epoch 7/20
# 81/81 [==============================] - 4s 49ms/step - loss: 0.3740 - acc: 0.8694 - auc: 0.6531 - val_loss: 0.3613 - val_acc: 0.8639 - val_auc: 0.7704
# Epoch 8/20
# 81/81 [==============================] - 4s 50ms/step - loss: 0.3729 - acc: 0.8691 - auc: 0.6618 - val_loss: 0.3587 - val_acc: 0.8639 - val_auc: 0.7693
# Epoch 9/20
# 81/81 [==============================] - 4s 49ms/step - loss: 0.3528 - acc: 0.8694 - auc: 0.7313 - val_loss: 0.3617 - val_acc: 0.8472 - val_auc: 0.7833
# Epoch 10/20
# 81/81 [==============================] - 4s 49ms/step - loss: 0.3356 - acc: 0.8707 - auc: 0.7682 - val_loss: 0.3334 - val_acc: 0.8667 - val_auc: 0.7987
# Epoch 11/20
# 81/81 [==============================] - 4s 48ms/step - loss: 0.3405 - acc: 0.8716 - auc: 0.7602 - val_loss: 0.3473 - val_acc: 0.8583 - val_auc: 0.8080
# Epoch 12/20
# 81/81 [==============================] - 4s 48ms/step - loss: 0.3325 - acc: 0.8685 - auc: 0.7727 - val_loss: 0.3396 - val_acc: 0.8556 - val_auc: 0.8007
# Epoch 13/20
# 81/81 [==============================] - 4s 49ms/step - loss: 0.3281 - acc: 0.8670 - auc: 0.7861 - val_loss: 0.3512 - val_acc: 0.8694 - val_auc: 0.7992
# Epoch 14/20
# 81/81 [==============================] - 4s 49ms/step - loss: 0.3347 - acc: 0.8716 - auc: 0.7731 - val_loss: 0.3282 - val_acc: 0.8611 - val_auc: 0.8083
# Epoch 15/20
# 81/81 [==============================] - 4s 49ms/step - loss: 0.3291 - acc: 0.8707 - auc: 0.7866 - val_loss: 0.4284 - val_acc: 0.8472 - val_auc: 0.8064
# Epoch 16/20
# 81/81 [==============================] - 4s 48ms/step - loss: 0.3408 - acc: 0.8676 - auc: 0.7640 - val_loss: 0.3323 - val_acc: 0.8639 - val_auc: 0.8024
# Epoch 17/20
# 81/81 [==============================] - 4s 48ms/step - loss: 0.3308 - acc: 0.8713 - auc: 0.7760 - val_loss: 0.3550 - val_acc: 0.8694 - val_auc: 0.8183
# Epoch 18/20
# 81/81 [==============================] - 4s 49ms/step - loss: 0.3257 - acc: 0.8735 - auc: 0.7824 - val_loss: 0.3263 - val_acc: 0.8556 - val_auc: 0.8120
# Epoch 19/20
# 81/81 [==============================] - 4s 49ms/step - loss: 0.3186 - acc: 0.8731 - auc: 0.7988 - val_loss: 0.3225 - val_acc: 0.8611 - val_auc: 0.8130
# Epoch 20/20
# 81/81 [==============================] - 4s 49ms/step - loss: 0.3204 - acc: 0.8762 - auc: 0.7994 - val_loss: 0.3615 - val_acc: 0.8694 - val_auc: 0.8088

# %%
# epoch별 model acc 비교하기 

import matplotlib.pyplot as plt

history = history.history
history
loss = history['loss']
acc = history['acc']
auc = history['auc']
val_loss = history['val_loss']
val_acc = history['val_acc']
val_auc = history['val_auc']
length = len(val_loss)

plt.plot(range(length), auc, 'ro', label='AUC')
plt.plot(range(length), val_auc, 'b-', label='val_AUC')
plt.xlabel('epochs')
plt.ylabel('AUC')
plt.legend()

# %%
# epoch별 모델 loss 확인하기

plt.plot(range(length), loss, 'ro', label='loss')
plt.plot(range(length), val_loss, 'b-', label='val_loss')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()

# %%
# test loss, acc, auc 구하기1
test_loss, test_acc, test_auc = bidirec_model.evaluate(X_test_3d, y_test_3d)
print(f'test_acc: {test_acc:.4f}')
print(f'test_auc: {test_auc:.4f}')


# auroc 구하기2
from sklearn.metrics import roc_auc_score

test_pred = bidirec_model.predict(X_test_3d)
auc = roc_auc_score(y_test_3d, test_pred)

print(f'acc_test: {test_acc:.4f}')
print(f'auc_score_test: {auc:.4f}')
# Out:
# 13/13 [==============================] - 1s 15ms/step - loss: 0.3467 - acc: 0.8775 - auc: 0.8196
# test_acc: 0.8775
# test_auc: 0.8196
# 13/13 [==============================] - 1s 13ms/step
# acc_test: 0.8775
# auc_score_test: 0.8197

# %%
bidirec_model.save(path+'bidirec_model_best_upto.h5')

# %%
from keras.models import load_model
from sklearn.metrics import roc_auc_score

loaded_model = load_model(path+'bidirec_model_best_upto.h5')

test_loss, test_acc, test_auc = loaded_model.evaluate(X_test_3d, y_test_3d)
test_pred = loaded_model.predict(X_test_3d)
auc = roc_auc_score(y_test_3d, test_pred)

print(f'acc_test: {test_acc:.4f}')
print(f'auc_score_test: {auc:.4f}')
# Out:
# 13/13 [==============================] - 1s 14ms/step - loss: 0.3467 - acc: 0.8775 - auc: 0.8196
# 13/13 [==============================] - 1s 13ms/step
# acc_test: 0.8775
# auc_score_test: 0.8197
